# %% [markdown]
# Questão 1

# %%
valor = 0
total = 0
maior = 0
idade = 0
while idade !=-1: 
  idade = int (input("Insira a idade: ")) 
  if idade !=-1: 
    sexo = (input("Insira o sexo: ")) 
    olhos = (input("Insira a cor dos olhos: ")) 
    cabelo = (input("Insira a cor do cabelo: ")) 
    if idade >= 18 and idade <=35: 
      if sexo == 'f' or 'feminino': 
        if olhos == 'v' or 'verdes': 
          if cabelo == 'l' or 'louros': 
            total += 1 
  if idade>maior: 
    maior = idade
print("A maior idade dos habitantes: ", maior)
print("Indivíduos do sexo feminino com olhos verdes, cabelos louros, e idade entre 18 e 35 anos:", total, end='')
# Out:
# Insira a idade: 19
# Insira o sexo(f= feminino ou m=masculino): f
# Insira a cor dos olhos(a = azuis, v = verdes, c = castanhos): v
# Insira a cor do cabelo(p = pretos, l = louros, c = castranhos): l
# Insira a idade: 20
# Insira o sexo(f= feminino ou m=masculino): feminino
# Insira a cor dos olhos(a = azuis, v = verdes, c = castanhos): verdes
# Insira a cor do cabelo(p = pretos, l = louros, c = castranhos): louros
# Insira a idade: 35
# Insira o sexo(f= feminino ou m=masculino): feminino
# Insira a cor dos olhos(a = azuis, v = verdes, c = castanhos): v
# Insira a cor do cabelo(p = pretos, l = louros, c = castranhos): l
# Insira a idade: -1
# A maior idade dos habitantes:  35
# Indivíduos do sexo feminino com olhos verdes, cabelos louros, e idade entre 18 e 35 anos: 3
