# %% [markdown]
# 1) Implemente um programa que exiba a tabuada do 2 ao 9.

# %%
for valor in range(2,10):
  for i in range(1,11):
    print(i,"X",valor,"=",i*valor,sep='') 
  print()
# Out:
# 1X2=2
# 2X2=4
# 3X2=6
# 4X2=8
# 5X2=10
# 6X2=12
# 7X2=14
# 8X2=16
# 9X2=18
# 10X2=20
#
# 1X3=3
# 2X3=6
# 3X3=9
# 4X3=12
# 5X3=15
# 6X3=18
# 7X3=21
# 8X3=24
# 9X3=27
# 10X3=30
#
# 1X4=4
# 2X4=8
# 3X4=12
# 4X4=16
# 5X4=20
# 6X4=24
# 7X4=28
# 8X4=32
# 9X4=36
# 10X4=40
#
# 1X5=5
# 2X5=10
# 3X5=15
# 4X5=20
# 5X5=25
# 6X5=30
# 7X5=35
# 8X5=40
# 9X5=45
# 10X5=50
#
# 1X6=6
# 2X6=12
# 3X6=18
# 4X6=24
# 5X6=30
# 6X6=36
# 7X6=42
# 8X6=48
# 9X6=54
# 10X6=60
#
# 1X7=7
# 2X7=14
# 3X7=21
# 4X7=28
# 5X7=35
# 6X7=42
# 7X7=49
# 8X7=56
# 9X7=63
# 10X7=70
#
# 1X8=8
# 2X8=16
# 3X8=24
# 4X8=32
# 5X8=40
# 6X8=48
# 7X8=56
# 8X8=64
# 9X8=72
# 10X8=80
#
# 1X9=9
# 2X9=18
# 3X9=27
# 4X9=36
# 5X9=45
# 6X9=54
# 7X9=63
# 8X9=72
# 9X9=81
# 10X9=90

# %% [markdown]
# 2) Faça um programa para tabular a função: f(x, y) = (x4 +3xy+y3 )/(2xy+3x+4y+2) para x = 2, 4, 6, 8 e y = 1, 3, 5, 7, 9, para cada valor de x. Devem ser impressos os valores de x, de y e de f(x,y).

# %%
# %reset -f
for x  in range(2,9,2):
  for y in range(1,10,2):
    f=(x**4+3*x*y+y**3)/(2*x*y+3*x+4*y+2)
    print('f(',x,',',y,') = ',f, sep='')
  print()
# Out:
# f(2,1) = 1.4375
# f(2,3) = 1.90625
# f(2,5) = 3.5625
# f(2,7) = 6.265625
# f(2,9) = 9.9875
#
# f(4,1) = 10.346153846153847
# f(4,3) = 6.38
# f(4,5) = 5.95945945945946
# f(4,7) = 6.969387755102041
# f(4,9) = 8.959016393442623
#
# f(6,1) = 36.52777777777778
# f(6,3) = 20.25
# f(6,5) = 15.11
# f(6,7) = 13.371212121212121
# f(6,9) = 13.335365853658537
#
# f(8,1) = 89.58695652173913
# f(8,3) = 48.77906976744186
# f(8,5) = 34.45238095238095
# f(8,7) = 27.753012048192772
# f(8,9) = 24.47087378640777

# %%
ch = input("Caractere: ")
for linha in range(8):
    for coluna in range(8):
        if (linha + coluna) % 2 == 0:
            print(ch, ch, sep = '', end = '')
        else:
            print('  ', sep = '', end = '')
    print()
# Out:
# Caractere: *
# **  **  **  **
#   **  **  **  **
# **  **  **  **
#   **  **  **  **
# **  **  **  **
#   **  **  **  **
# **  **  **  **
#   **  **  **  **

# %% [markdown]
# Questão 3

# %%
ch = "*"
for linha in range(8):
    for coluna in range(8):
        if coluna:
            print(ch, ch, sep = '', end = '')
    print()
# Out:
# **************
# **************
# **************
# **************
# **************
# **************
# **************
# **************

# %% [markdown]
# Questão 4

# %%
ch = "*"
for linha in range(8):
    for coluna in range(8):
        if coluna==linha or (linha+coluna==8-1):
            print(ch, ch, sep = '', end = '')
        else:
          print(" ",sep = "",end = "")
    print()
# Out:
# *
# **
# ***
# ****
# *****
# ******
# *******
# ********
# *********
# **********

# %% [markdown]
# Questão 5

# %%
ch = "*"
for linha in range(8):
    for coluna in range(8):
        if coluna==linha or (linha+coluna==8-1):
            print(ch, ch, sep = '', end = '')
        else:
          print(" ",sep = "",end = "")
    print()
# Out:
# **      **
#  **    **
#   **  **
#    ****
#    ****
#   **  **
#  **    **
# **      **

# %% [markdown]
# Questão 7

# %%
ch = '*'
tam = 10
for linha in range(tam):
    for coluna in range(tam):
        if (linha <= coluna):
            print(ch, sep = '', end = '')
        else:
            print('', sep = '', end = '')
    print()
# Out:
# **********
# *********
# ********
# *******
# ******
# *****
# ****
# ***
# **
# *
